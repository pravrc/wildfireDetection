# %%
# !git clone https://github.com/pravrc/yolov3.git
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 750, done.
# remote: Counting objects: 100% (750/750), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 750 (delta 696), reused 750 (delta 696), pack-reused 0
# Receiving objects: 100% (750/750), 276.73 KiB | 9.22 MiB/s, done.
# Resolving deltas: 100% (696/696), done.

# %%
# !ls
# Out:
# 'bh-w-mobo-c__2019-06-10T13;41;16.jpg'	 __pycache__
#  callbacks.py				 README.md
#  config.json				 traindata
#  data					 train.py
#  evaluate.py				 utils
#  gen_anchors.py				 voc.py
#  generator.py				 yolo3_one_file_to_detect_them_all.py
#  HackathonFuego_train.pkl		 yolo.py
#  LICENSE				 yolov3
#  output					 zoo
#  predict.py

# %%
# !wget "https://www.dropbox.com/s/ghfhjtoh1z59xeb/wildfire_smoke_data.tar"
# !tar -xvf 'wildfire_smoke_data.tar'
# Out:
# --2020-01-27 03:55:29--  https://www.dropbox.com/s/ghfhjtoh1z59xeb/wildfire_smoke_data.tar
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ghfhjtoh1z59xeb/wildfire_smoke_data.tar [following]
# --2020-01-27 03:55:29--  https://www.dropbox.com/s/raw/ghfhjtoh1z59xeb/wildfire_smoke_data.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5965c20f9c19677a8641a016fd.dl.dropboxusercontent.com/cd/0/inline/Aw-BtCANV32vYfESezxgEyj24v71TFC7qP1VJqtRCw1tXg_aqmSuv7Bqaa5qcx9CklMuxSuGW4QVho0vAgIIkDMGCJS_LhITJyh7VzFHZab-c_xQHwScTT4J7NmOKyTksic/file# [following]
# ...

# %%
# !mkdir -p smoke_images
# !cp -r wildfire_smoke_data/validate/smoke/* smoke_images

# %%
# !cp -r wildfire_smoke_data/train/smoke/* smoke_images

# %%
# !ls smoke_images | wc -l
# Out:
# 143

# %%
# !unzip /content/yolov3/data/train/annotations/annotation.zip
# Out:
# Archive:  /content/yolov3/data/train/annotations/annotation.zip
#   inflating: no_smoke_id.txt
#    creating: __MACOSX/
#   inflating: __MACOSX/._no_smoke_id.txt
#    creating: smoke_annotation/
#   inflating: smoke_annotation/1498416813_+00420.xml
#   inflating: smoke_annotation/1498416873_+00480.xml
#   inflating: smoke_annotation/1498416933_+00540.xml
#   inflating: smoke_annotation/1498416993_+00600.xml
#   inflating: smoke_annotation/1498417053_+00660.xml
#   inflating: smoke_annotation/1498417113_+00720.xml
#   inflating: smoke_annotation/1498417173_+00780.xml
#   inflating: smoke_annotation/1498417233_+00840.xml
#   inflating: smoke_annotation/1498417293_+00900.xml
#   inflating: smoke_annotation/1498417353_+00960.xml
#   inflating: smoke_annotation/1498417413_+01020.xml
#   inflating: smoke_annotation/1498417473_+01080.xml
#   inflating: smoke_annotation/1498417533_+01140.xml
#   inflating: smoke_annotation/1498417593_+01200.xml
# ...

# %%
# %%writefile /content/yolov3/config.json
# {
#     "model" : {
#         "min_input_size":       288,
#         "max_input_size":       448,
#         "anchors":              [55,69, 75,234, 133,240, 136,129, 142,363, 203,290, 228,184, 285,359, 341,260],
#         "labels":               ["fire"]
#     },
#
#     "train": {
#         "train_image_folder":   "/content/smoke_images/",
#         "train_annot_folder":   "/content/smoke_annotation/",
#         "cache_name":           "",
#
#         "train_times":          8,
#         "batch_size":           16,
#         "learning_rate":        1e-4,
#         "nb_epochs":            100,
#         "warmup_epochs":        3,
#         "ignore_thresh":        0.5,
#         "gpus":                 "0",
#
#         "grid_scales":          [1,1,1],
#         "obj_scale":            5,
#         "noobj_scale":          1,
#         "xywh_scale":           1,
#         "class_scale":          1,
#
#         "tensorboard_dir":      "logs",
#         "saved_weights_name":   "HackathonFuego.h5",
#         "debug":                true
#     },
#
#     "valid": {
#         "valid_image_folder":   "",
#         "valid_annot_folder":   "",
#         "cache_name":           "",
#
#         "valid_times":          1
#     }
# }
# Out:
# Overwriting /content/yolov3/config.json

# %%
#!wget https://drive.google.com/open?id=1o_PM_zB6FxJRdLpEx8lEAhL29IMe1KzI
#!wget --no-check-certificate -r 'https://drive.google.com/uc?export=download&id=1o_PM_zB6FxJRdLpEx8lEAhL29IMe1KzI' -O backend.h5
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from pathlib import Path
#!ls /content/gdrive/My\ Drive
GPATH = '/content/gdrive/My Drive/'
GPATH = Path(GPATH)
GPATH
# Out:
# PosixPath('/content/gdrive/My Drive')

# %%
# !cp -r /content/gdrive/My\ Drive/backend.h5 /content/yolov3/

# %%
# %cd yolov3
# !python train.py -c config.json
# Out:
# [Errno 2] No such file or directory: 'yolov3'
# /content/yolov3
# Using TensorFlow backend.
# Traceback (most recent call last):
#   File "train.py", line 282, in <module>
#     _main_(args)
#   File "train.py", line 182, in _main_
#     config['model']['labels']
#   File "train.py", line 29, in create_training_instances
#     train_ints, train_labels = parse_voc_annotation(train_annot_folder, train_image_folder, train_cache, labels)
#   File "/content/yolov3/voc.py", line 15, in parse_voc_annotation
#     for ann in sorted(os.listdir(ann_dir)):
# FileNotFoundError: [Errno 2] No such file or directory: '/content/smoke_annotation/'

# %%
# !ls
#!cp HackathonFuego.h5 /content/gdrive/My\ Drive
# !cp HackathonFuego_train.pkl /content/gdrive/My\ Drive
# Out:
# callbacks.py	HackathonFuego_train.pkl  train.py
# config.json	LICENSE			  utils
# data		predict.py		  voc.py
# evaluate.py	__pycache__		  yolo3_one_file_to_detect_them_all.py
# gen_anchors.py	README.md		  yolo.py
# generator.py	traindata		  zoo

# %%
import glob
class_names=['fire']
img_names = glob.glob('/content/smoke_images/*.jpg')
class_names
len(img_names)
img = Image.open(img_names[0])
draw = ImageDraw.Draw(img)

# %% [markdown]
# Predict

# %%
# !cp /content/gdrive/My\ Drive/HackathonFuego.h5 yolov3

# %%
from google.colab import files
files.upload()
# !ls
# Out:
#      <input type="file" id="files-8df17f77-8c07-4eca-82ca-8347ae239a6c" name="files[]" multiple disabled />
#      <output id="result-8df17f77-8c07-4eca-82ca-8347ae239a6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 69bravo-e-mobo-c__2019-08-13T14;27;44.jpg to 69bravo-e-mobo-c__2019-08-13T14;27;44.jpg
# '69bravo-e-mobo-c__2019-08-13T14;21;44.jpg'
# '69bravo-e-mobo-c__2019-08-13T14;22;44.jpg'
# '69bravo-e-mobo-c__2019-08-13T14;26;44.jpg'
# '69bravo-e-mobo-c__2019-08-13T14;27;44.jpg'
# '69bravo-e-mobo-c__2019-08-13T14;28;44.jpg'
# '69bravo-e-mobo-c__2019-08-13T14;30;44.jpg'
# '69bravo-e-mobo-c__2019-08-13T14;43;44.jpg'
#  callbacks.py
#  config.json
#  data
#  evaluate.py
#  gen_anchors.py
#  generator.py
#  HackathonFuego.h5
#  HackathonFuego_train.pkl
#  LICENSE
# ...

# %%
# !ls /content/sample_data/yolov3
# Out:
# ls: cannot access '/content/sample_data/yolov3': No such file or directory

# %%
# !python predict.py -c config.json -i '69bravo-e-mobo-c__2019-08-13T14;26;44.jpg'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
# !ls -l output
# Out:
# total 3388
# -rw-r--r-- 1 root root  942420 Jan 29 19:04 '69bravo-e-mobo-c__2019-08-13T14;43;44.jpg'
# -rw-r--r-- 1 root root 1155787 Jan 29 19:30 'lp-s-mobo-c__2019-10-06T11;45;05.jpg'
# -rw-r--r-- 1 root root 1360025 Jan 29 19:34 'wc-s-mobo-c__2019-09-25T13;28;22.jpg'

# %%
import IPython.display as display
from PIL import Image
img = Image.open('./output/69bravo-e-mobo-c__2019-08-13T14;26;44.jpg')
display.display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %cd yolov3/
# !python predict.py -c config.json -i /content/smoke_images/1530739525_+00480.jpg
# Out:
# /content/yolov3
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
import IPython.display as display
from PIL import Image
img = Image.open('./output/1530739525_+00480.jpg')
display.display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
